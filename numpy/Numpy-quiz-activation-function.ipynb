# %% [markdown]
# # Activation Functions 구현해보기

# %% [markdown]
# 인풋 x 는 numpy의 ndarray 객체라고 가정.

# %%
import numpy as np

# %% [markdown]
# ## Binary Step Function

# %% [markdown]
# $$ f(x)={\begin{cases}0&{\text{for }}x<0\\1&{\text{for }}x\geq 0\end{cases}}$$

# %%
def step_function(x):
    return

# %% [markdown]
# ## Sigmoid function - Logistic function

# %% [markdown]
# $$f(x)=\sigma (x)={\frac {1}{1+e^{-x}}}$$

# %%
def logistic(x):
    return

# %% [markdown]
# ## Sigmoid function - Hyperbolic tangent

# %% [markdown]
# $$f(x)=\tanh(x)={\frac {(e^{x}-e^{-x})}{(e^{x}+e^{-x})}}$$
#
# * numpy.tanh 와 비교해보기

# %%
def tanh(x):
    return

# %%
arr = np.arange(-3, 3, 1)
print(np.tanh(arr))
print(tanh(arr))
# Out:
# [-0.99505475 -0.96402758 -0.76159416  0.          0.76159416  0.96402758]
# [-0.99505475 -0.96402758 -0.76159416  0.          0.76159416  0.96402758]

# %% [markdown]
# ## ReLU(Rectified Linear Unit)

# %% [markdown]
# $$f(x)={\begin{cases}0&{\text{for }}x\leq 0\\x&{\text{for }}x>0\end{cases}}$$

# %%
def relu(x):
    return

# %% [markdown]
# ## Leaky ReLU

# %% [markdown]
# $$ f(x)={\begin{cases}0.01x&{\text{for }}x<0\\x&{\text{for }}x\geq 0\end{cases}}$$

# %%
def leakyrelu(x):
    return

# %% [markdown]
# ## Parametric ReLU

# %% [markdown]
# $$ f(\alpha ,x)={\begin{cases}\alpha x&{\text{for }}x<0\\x&{\text{for }}x\geq 0\end{cases}}$$

# %%
def parametric_relu(x, a):
    """
    LeakyReLU 
    Args:
        x (numpy.ndarray): the input numpy ndarray object
        a (float): the coefficient of leakage (nonzero)
    Returns:
        numpy.array: the output of the Parametric LeakyReLU 
    """
    return

# %% [markdown]
# ## softmax

# %% [markdown]
# $$f_{i}(x)={\frac {e^{x_{i}}}{\sum _{j=1}^{J}e^{x_{j}}}}$$

# %%
def softmax(x):

    return
