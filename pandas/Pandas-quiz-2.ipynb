# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 0.
# quiz1에서와 같이 stock 데이터 읽어오기
# stock = pd.read_csv('파일 있는 주소'+'/quiz-1-stock.csv')

# %%
stock =

# %% [markdown]
# # 1.
# sales_1, sales_2는 각각 1월 판매량, 2월 판매량이라고 할 때,
# 1월 수치와 2월 수치를 합친 수치를 출력해보기

# %%
np.random.seed(2020)
newspaper1 = ['경향신문신문', '국민일보신문', '동아일보신문', '문화일보신문', '서울신문신문', '세계일보신문','조선일보신문',  '중앙일보신문', '한겨레신문', '한국일보신문']
newspaper2 = ['경향신문신문', '국민일보신문', '동아일보신문', '문화일보신문', '서울신문신문', '세계일보신문']

sales1 = pd.Series(np.random.randint(1000, 9999, 10)*100, index=newspaper1)
sales2 = pd.Series(np.random.randint(1000, 9999, 6)*100, index=newspaper2)

# %%
'''
output:
경향신문신문    1493600.0
국민일보신문     674700.0
동아일보신문     893700.0
문화일보신문    1362900.0
서울신문신문    1235300.0
세계일보신문    1760100.0
조선일보신문          NaN
중앙일보신문          NaN
한겨레신문           NaN
한국일보신문          NaN
dtype: float64
'''
# Out:
# 경향신문신문    1493600.0
# 국민일보신문     674700.0
# 동아일보신문     893700.0
# 문화일보신문    1362900.0
# 서울신문신문    1235300.0
# 세계일보신문    1760100.0
# 조선일보신문          NaN
# 중앙일보신문          NaN
# 한겨레신문           NaN
# 한국일보신문          NaN
# dtype: float64

# %% [markdown]
# # 2.
# 각 신문사가 1월 대비 2월에 몇 % 상승했는지 구해보기

# %%
'''
output:
경향신문신문    -24.096102
국민일보신문     14.941064
동아일보신문    135.851184
문화일보신문     92.781955
서울신문신문     35.160860
세계일보신문    -19.513946
조선일보신문           NaN
중앙일보신문           NaN
한겨레신문            NaN
한국일보신문           NaN
dtype: float64
'''
# Out:
# 경향신문신문    -24.096102
# 국민일보신문     14.941064
# 동아일보신문    135.851184
# 문화일보신문     92.781955
# 서울신문신문     35.160860
# 세계일보신문    -19.513946
# 조선일보신문           NaN
# 중앙일보신문           NaN
# 한겨레신문            NaN
# 한국일보신문           NaN
# dtype: float64

# %% [markdown]
# # 3.
# stock 데이터의 '체결가','거래량(천주)', '거래대금(백만)' 컬럼에 대해 각각의 최대값, 최소값을 하나의 리스트로 반환.
#
# hint: apply 사용(원소별로 함수를 적용하는 것이 아니라 축 별로 적용하는 것이므로 apply 사용)

# %%
'''
체결가             [2267.25, 2118.88]
거래량(천주)       [836699.0, 488288.0]
거래대금(백만)    [8818232.0, 5444383.0]
dtype: object
'''
# Out:
# 체결가             [2267.25, 2118.88]
# 거래량(천주)       [836699.0, 488288.0]
# 거래대금(백만)    [8818232.0, 5444383.0]
# dtype: object

# %% [markdown]
# # 4.
# sales1 데이터에 score 라고 정의된 사용자 함수를 적용해서 각 신문사의 등급을 확인해보자.

# %%
def score(x):
    return 'A' if x > 500000 else 'B'

# %%
'''
output:
경향신문신문    A
국민일보신문    B
동아일보신문    B
문화일보신문    B
서울신문신문    A
세계일보신문    A
조선일보신문    B
중앙일보신문    A
한겨레신문     B
한국일보신문    B
dtype: object
'''
# Out:
# 경향신문신문    A
# 국민일보신문    B
# 동아일보신문    B
# 문화일보신문    B
# 서울신문신문    A
# 세계일보신문    A
# 조선일보신문    B
# 중앙일보신문    A
# 한겨레신문     B
# 한국일보신문    B
# dtype: object

# %% [markdown]
# # 5.
# sales2를 통해 가장 높게 팔린 순으로 정렬해보기

# %%
'''
output:
문화일보신문    897400
세계일보신문    784900
서울신문신문    710000
경향신문신문    644500
동아일보신문    627600
국민일보신문    360800
dtype: int64
'''
# Out:
# 문화일보신문    897400
# 세계일보신문    784900
# 서울신문신문    710000
# 경향신문신문    644500
# 동아일보신문    627600
# 국민일보신문    360800
# dtype: int64

# %% [markdown]
# # 6.
# sales1을 신문사 명을 오름차순으로 정렬

# %%
'''
output:
경향신문신문    849100
국민일보신문    313900
동아일보신문    266100
문화일보신문    465500
서울신문신문    525300
세계일보신문    975200
조선일보신문    299400
중앙일보신문    689700
한겨레신문     162600
한국일보신문    187000
dtype: int64
'''
# Out:
# 경향신문신문    849100
# 국민일보신문    313900
# 동아일보신문    266100
# 문화일보신문    465500
# 서울신문신문    525300
# 세계일보신문    975200
# 조선일보신문    299400
# 중앙일보신문    689700
# 한겨레신문     162600
# 한국일보신문    187000
# dtype: int64

# %% [markdown]
# # 7.
# stock 데이터의 거래량이 높은 순서대로 정렬해보자.

# %%
'''
 	날짜 	체결가 	전일비 	등락률 	거래량(천주) 	거래대금(백만)
10 	2020.01.22 	2267.25 	상승 27.56 	1% 	608509 	6365617
12 	2020.01.20 	2262.64 	상승 12.07 	1% 	545491 	5950403
13 	2020.01.17 	2250.57 	상승 2.52 	0% 	580816 	5444383
14 	2020.01.16 	2248.05 	상승 17.07 	1% 	808331 	6204474
9 	2020.01.23 	2246.13 	하락 21.12 	-1% 	509608 	6790103
11 	2020.01.21 	2239.69 	하락 22.95 	-1% 	770319 	5569550
'''
# Out:
#              날짜      체결가        전일비  등락률  거래량(천주)  거래대금(백만)
# 10  2020.01.22   2267.25  상승 27.56    1%   608509   6365617
# 12  2020.01.20   2262.64  상승 12.07    1%   545491   5950403
# 13  2020.01.17   2250.57   상승 2.52    0%   580816   5444383
# 14  2020.01.16   2248.05  상승 17.07    1%   808331   6204474
# 9   2020.01.23   2246.13  하락 21.12   -1%   509608   6790103
# 11  2020.01.21   2239.69  하락 22.95   -1%   770319   5569550
# 16  2020.01.14   2238.88   상승 9.62    0%   835899   7294227
# 15  2020.01.15   2230.98   하락 7.90    0%   746156   5946351
# 17  2020.01.13   2229.26  상승 22.87    1%   488288   6214780
# 1   2020.02.06   2227.94  상승 62.31    3%   695216   8334737
# 0   2020.02.07   2211.95  하락 15.99   -1%   800342   8813174
# 7   2020.01.29   2185.28   상승 8.56    0%   692300   6589949
# 8   2020.01.28   2176.72  하락 69.41   -3%   808878   8818232
# 2   2020.02.05   2165.63   상승 7.73    0%   574395   7736275
# 3   2020.02.04   2157.90  상승 39.02    2%   624641   7791178
# ...

# %% [markdown]
# # 8
# stock 데이터의 mean과 median을 확인해보기

# %%
print('mean')
'''
mean

체결가         2.206931e+03
거래량(천주)     6.799574e+05
거래대금(백만)    7.014668e+06
dtype: float64
'''
# Out:
# mean
# 체결가         2.206931e+03
# 거래량(천주)     6.799574e+05
# 거래대금(백만)    7.014668e+06
# dtype: float64

# %%
print('median')
'''
output:
median
체결가            2228.6
거래량(천주)      693758.0
거래대금(백만)    6947653.0
dtype: float64

'''
# Out:
# median
# 체결가            2228.6
# 거래량(천주)      693758.0
# 거래대금(백만)    6947653.0
# dtype: float64

# %% [markdown]
# # 9
# stock 데이터의 각 컬럼끼리의 correlation 을 출력

# %%
'''
output:
 	    체결가 	거래량(천주) 	거래대금(백만)
체결가   	1.000000 	-0.212919 	-0.550380
거래량(천주) 	-0.212919 	1.000000 	0.372256
거래대금(백만) 	-0.550380 	0.372256 	1.000000
'''
# Out:
#                체결가   거래량(천주)  거래대금(백만)
# 체결가       1.000000 -0.212919 -0.550380
# 거래량(천주)  -0.212919  1.000000  0.372256
# 거래대금(백만) -0.550380  0.372256  1.000000
